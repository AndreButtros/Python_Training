# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreButtros/Python_Training/blob/main/Drink_Sales_Analisys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.read_excel('/content/dados.xlsx', sheet_name='Por Canal')
df1
# Out:
#                         Estabelecimento        Data      Dia   Modo  \
# 0     JAPPA DA QUITANDA - ANÁLIA FRANCO  2025-08-01    Sexta  Salão
# 1     JAPPA DA QUITANDA - ANÁLIA FRANCO  2025-08-02   Sábado  Salão
# 2     JAPPA DA QUITANDA - ANÁLIA FRANCO  2025-08-03  Domingo  Salão
# 3     JAPPA DA QUITANDA - ANÁLIA FRANCO  2025-08-04  Segunda  Salão
# 4     JAPPA DA QUITANDA - ANÁLIA FRANCO  2025-08-05    Terça  Salão
# ..                                  ...         ...      ...    ...
# 163  JAPPA DA QUITANDA - BARRA SHOPPING  2025-09-23    Terça  Salão
# 164  JAPPA DA QUITANDA - BARRA SHOPPING  2025-09-24   Quarta  Salão
# 165  JAPPA DA QUITANDA - BARRA SHOPPING  2025-09-24   Quarta  Salão
# 166  JAPPA DA QUITANDA - BARRA SHOPPING  2025-09-25   Quinta  Salão
# 167  JAPPA DA QUITANDA - BARRA SHOPPING  2025-09-25   Quinta  Salão
#
#      Integração  Tabela Preço  N.Pessoas
# 0             0             0        201
# 1             0             0        266
# ...

# %%
df2 = pd.read_excel('/content/dados.xlsx', sheet_name='Consumo de Produtos')
df2
# Out:
#                         Estabelecimento  Cod.         Categoria  \
# 0     JAPPA DA QUITANDA - ANÁLIA FRANCO  2000          RENTRADA
# 1     JAPPA DA QUITANDA - ANÁLIA FRANCO  2001          RENTRADA
# 2     JAPPA DA QUITANDA - ANÁLIA FRANCO  2002          RENTRADA
# 3     JAPPA DA QUITANDA - ANÁLIA FRANCO  2003  R PRATOS QUENTES
# 4     JAPPA DA QUITANDA - ANÁLIA FRANCO  2004          RENTRADA
# ..                                  ...   ...               ...
# 809  JAPPA DA QUITANDA - BARRA SHOPPING  3740           CERVEJA
# 810  JAPPA DA QUITANDA - BARRA SHOPPING  3741       SOFT DRINKS
# 811  JAPPA DA QUITANDA - BARRA SHOPPING  3742       SOFT DRINKS
# 812  JAPPA DA QUITANDA - BARRA SHOPPING  3744       VINHO TINTO
# 813  JAPPA DA QUITANDA - BARRA SHOPPING  3745           CERVEJA
#
#                           Descrição  Quant. T. Categoria
# 0                        R SUNOMONO       0      RODIZIO
# 1                R CAMARAO CATUPIRY       0      RODIZIO
# ...

# %%
df2 = df2[df2['T. Categoria'].isin(['DRINKS', 'SOFT DRINKS'])]
df2
# Out:
#                         Estabelecimento  Cod.        Categoria  \
# 158   JAPPA DA QUITANDA - ANÁLIA FRANCO  3103      SOFT DRINKS
# 159   JAPPA DA QUITANDA - ANÁLIA FRANCO  3104      SOFT DRINKS
# 160   JAPPA DA QUITANDA - ANÁLIA FRANCO  3105      SOFT DRINKS
# 161   JAPPA DA QUITANDA - ANÁLIA FRANCO  3106      SOFT DRINKS
# 162   JAPPA DA QUITANDA - ANÁLIA FRANCO  3107      SOFT DRINKS
# ..                                  ...   ...              ...
# 802  JAPPA DA QUITANDA - BARRA SHOPPING  3667      SOFT DRINKS
# 803  JAPPA DA QUITANDA - BARRA SHOPPING  3668  DRINKS AUTORAIS
# 807  JAPPA DA QUITANDA - BARRA SHOPPING  3704            SAKES
# 810  JAPPA DA QUITANDA - BARRA SHOPPING  3741      SOFT DRINKS
# 811  JAPPA DA QUITANDA - BARRA SHOPPING  3742      SOFT DRINKS
#
#                           Descrição  Quant. T. Categoria
# 158                    AGUA COM GAS     267  SOFT DRINKS
# 159                    AGUA SEM GAS     318  SOFT DRINKS
# ...

# %%
n_pessoas = df1.groupby('Estabelecimento')['N.Pessoas'].sum()
n_pessoas
# Out:
# Estabelecimento
# JAPPA DA QUITANDA - ANÁLIA FRANCO     13088
# JAPPA DA QUITANDA - BARRA SHOPPING    26563
# Name: N.Pessoas, dtype: int64

# %%
quant = df2.groupby(['Estabelecimento','T. Categoria'])['Quant.'].sum()
quant
# Out:
# Estabelecimento                     T. Categoria
# JAPPA DA QUITANDA - ANÁLIA FRANCO   DRINKS          13428
#                                     SOFT DRINKS      9433
# JAPPA DA QUITANDA - BARRA SHOPPING  DRINKS           1362
#                                     SOFT DRINKS     28408
# Name: Quant., dtype: int64

# %%
quant_pessoa = quant / n_pessoas
quant_pessoa
# Out:
# Estabelecimento                     T. Categoria
# JAPPA DA QUITANDA - ANÁLIA FRANCO   DRINKS          1.025978
#                                     SOFT DRINKS     0.720737
# JAPPA DA QUITANDA - BARRA SHOPPING  DRINKS          0.051274
#                                     SOFT DRINKS     1.069458
# dtype: float64

# %%
ax = quant_pessoa.plot.barh()
ax.bar_label(ax.containers[0], fmt='{:.2f}')
ax.set_xlim(0, ax.get_xlim()[1]*1.1);

# %%
top5 = df2.groupby(['Estabelecimento', 'T. Categoria', 'Descrição'])['Quant.'].sum()
top5 = top5.sort_values(ascending=False)
top5 = top5.groupby(['Estabelecimento', 'T. Categoria']).head(5)
top5 = top5.sort_index()
top5
# Out:
# Estabelecimento                     T. Categoria  Descrição
# JAPPA DA QUITANDA - ANÁLIA FRANCO   DRINKS        CARAJILLO 43                                345
#                                                   COSMOPOLITAN                                349
#                                                   HAKUSHIKA HONJOSO SHU TRADICIONAL 720ML     350
#                                                   JIM BEAM                                    346
#                                                   MARGARITA                                   344
#                                     SOFT DRINKS   CAFE DESCAFEINADO                           349
#                                                   MATE DO CHEPH                               681
#                                                   MATE MULE                                   333
#                                                   SCHWEPPES CITRUS                            595
# ...
